# %%
import pandas as pd

from sqlalchemy import create_engine

engine = create_engine('postgresql://airflow:airflow@172.18.0.8:5432/airlines')
conn = engine.connect()

# %%
df_2006 = pd.read_csv('2006.csv', nrows = 10)
df_2006
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2006      1          11          3      743         745     1024
# 1  2006      1          11          3     1053        1053     1313
# 2  2006      1          11          3     1915        1915     2110
# 3  2006      1          11          3     1753        1755     1925
# 4  2006      1          11          3      824         832     1015
# 5  2006      1          11          3      627         630      834
# 6  2006      1          11          3      825         820     1041
# 7  2006      1          11          3      942         945     1155
# 8  2006      1          11          3     1239        1245     1438
# 9  2006      1          11          3     1642        1645     1841
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 0        1018            US        343  ...     45       13          0
# 1        1318            US        613  ...     27       19          0
# ...

# %%
df_2006.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               10 non-null     int64
#  1   Month              10 non-null     int64
#  2   DayofMonth         10 non-null     int64
#  3   DayOfWeek          10 non-null     int64
#  4   DepTime            10 non-null     int64
#  5   CRSDepTime         10 non-null     int64
#  6   ArrTime            10 non-null     int64
#  7   CRSArrTime         10 non-null     int64
#  8   UniqueCarrier      10 non-null     object
#  9   FlightNum          10 non-null     int64
#  10  TailNum            10 non-null     object
#  11  ActualElapsedTime  10 non-null     int64
#  12  CRSElapsedTime     10 non-null     int64
#  13  AirTime            10 non-null     int64
#  14  ArrDelay           10 non-null     int64
#  15  DepDelay           10 non-null     int64
# ...

# %%
df_2007 = pd.read_csv('2007.csv', nrows = 10)
df_2007
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2007      1           1          1     1232        1225     1341
# 1  2007      1           1          1     1918        1905     2043
# 2  2007      1           1          1     2206        2130     2334
# 3  2007      1           1          1     1230        1200     1356
# 4  2007      1           1          1      831         830      957
# 5  2007      1           1          1     1430        1420     1553
# 6  2007      1           1          1     1936        1840     2217
# 7  2007      1           1          1      944         935     1223
# 8  2007      1           1          1     1537        1450     1819
# 9  2007      1           1          1     1318        1315     1603
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 0        1340            WN       2891  ...      4       11          0
# 1        2035            WN        462  ...      5        6          0
# ...

# %%
df_2007.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               10 non-null     int64
#  1   Month              10 non-null     int64
#  2   DayofMonth         10 non-null     int64
#  3   DayOfWeek          10 non-null     int64
#  4   DepTime            10 non-null     int64
#  5   CRSDepTime         10 non-null     int64
#  6   ArrTime            10 non-null     int64
#  7   CRSArrTime         10 non-null     int64
#  8   UniqueCarrier      10 non-null     object
#  9   FlightNum          10 non-null     int64
#  10  TailNum            10 non-null     object
#  11  ActualElapsedTime  10 non-null     int64
#  12  CRSElapsedTime     10 non-null     int64
#  13  AirTime            10 non-null     int64
#  14  ArrDelay           10 non-null     int64
#  15  DepDelay           10 non-null     int64
# ...

# %%
chunk_size = 100000

files = ['2006.csv', '2007.csv']

for file in files:
    with pd.read_csv(file, chunksize = chunk_size) as reader:
        for chunk in reader:
            chunk.to_sql('airlines', con=conn, if_exists='append', index=False
                         , chunksize = chunk_size)

# %%
cnt = conn.execute("SELECT COUNT(*) FROM airlines")
print(f'There are {[row[0] for row in cnt]} rows in DB')
# Out:
# There are [14595137] rows in DB
